# %%
import os
import re

BASE_DIR = os.getcwd()  

regex = re.compile(r'\wthread_side\w|r|\wthread_top')  


for root, dirs, files in os.walk(os.path.join(BASE_DIR, 'data')):
    for file in files:
        if filecontains := regex.search(file):
            print(f"length of file name: {len(file)}")
